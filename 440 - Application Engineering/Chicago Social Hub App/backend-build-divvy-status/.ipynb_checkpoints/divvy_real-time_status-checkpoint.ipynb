# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 7/13/2019


##################################################################################################

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

# es = Elasticsearch()
es=Elasticsearch('http://login@129.105.88.91:9200')

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

# Extract the body of the reply
response_body = response.read()
response_stations_info = response_stations_info.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066739,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '2'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066408,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 52,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '3'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066684,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '4'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066897,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '5'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066818,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 37,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '6'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066923,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '7'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066787,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '9'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066913,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '11'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066637,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '12'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066912,
#                         'num_bikes_available': 35,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '13'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066899,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '14'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066817,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '15'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066718,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '16'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066767,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 4,
#                         'num_ebikes_available': 0,
#                         'station_id': '17'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066710,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '18'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066825,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '19'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066905,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '20'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066800,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '21'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066819,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '22'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066692,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '23'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066880,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '24'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066924,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '25'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066924,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '26'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066615,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '27'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066787,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '28'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066751,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '29'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066707,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '30'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066800,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '31'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066755,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '32'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066885,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 27,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '33'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066810,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '34'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066893,
#                         'num_bikes_available': 37,
#                         'num_bikes_disabled': 3,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '35'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066847,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '36'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066898,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '37'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066915,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '38'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066709,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '39'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066840,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '40'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066919,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '41'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066675,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '42'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066739,
#                         'num_bikes_available': 40,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '43'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066842,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 4,
#                         'num_ebikes_available': 0,
#                         'station_id': '44'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066889,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '45'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066916,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 5,
#                         'num_ebikes_available': 0,
#                         'station_id': '46'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066758,
#                         'num_bikes_available': 26,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '47'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066661,
#                         'num_bikes_available': 23,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '48'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066906,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 37,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '49'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066923,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '50'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066864,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 27,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '51'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066851,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '52'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066844,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '53'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066911,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '54'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066656,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '55'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066922,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '56'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066694,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '57'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066924,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '58'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066892,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '59'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066674,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '60'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066809,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '61'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066912,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '62'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066675,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 4,
#                         'num_ebikes_available': 0,
#                         'station_id': '66'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066673,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '67'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066697,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 19,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '68'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066907,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '69'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066799,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '71'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066838,
#                         'num_bikes_available': 29,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '72'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066630,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '73'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066821,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '74'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066884,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 35,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '75'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066919,
#                         'num_bikes_available': 32,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 6,
#                         'num_ebikes_available': 0,
#                         'station_id': '76'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066809,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 28,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '77'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066850,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '80'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066642,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 32,
#                         'num_docks_disabled': 3,
#                         'num_ebikes_available': 0,
#                         'station_id': '81'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066808,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '84'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066747,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '85'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066736,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '86'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066621,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '87'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066927,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '88'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066741,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '89'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066886,
#                         'num_bikes_available': 42,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '90'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066695,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 26,
#                         'num_docks_disabled': 5,
#                         'num_ebikes_available': 0,
#                         'station_id': '91'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066887,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '92'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066731,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '93'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066837,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '94'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066738,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '95'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066841,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '96'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563064380,
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 38,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '97'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066920,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '98'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066678,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '99'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066824,
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '100'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066727,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
# ...
#                         'is_returning': 1,
#                         'last_reported': 1563066903,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '636'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066706,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '637'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066834,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 4,
#                         'num_ebikes_available': 0,
#                         'station_id': '638'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066793,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '639'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066720,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '640'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066894,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '641'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066912,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '642'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066843,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '643'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066763,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '644'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066746,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '645'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562870300,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '646'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562602596,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '647'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562990245,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '648'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562903883,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '649'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562601600,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '650'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562990378,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '651'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562602611,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '652'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066747,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '653'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066696,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '654'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066709,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '655'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066822,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 2,
#                         'num_ebikes_available': 0,
#                         'station_id': '656'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066741,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '657'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066736,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '658'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066739,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '659'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066820,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '660'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066808,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '661'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066776,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '662'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066764,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '663'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1563066726,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '664'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1562601599,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '665'}]},
#  'last_updated': 1563066929,
#  'ttl': 2}

# %%
pprint(stations_info_json)
# Out:
# {'data': {'stations': [{'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a36d9e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.86943,
#                         'lon': -87.622391,
#                         'name': 'Buckingham Fountain (Temp)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'T316041805',
#                         'station_id': '2'},
#                        {'capacity': 55,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37378-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.86722595682,
#                         'lon': -87.6153553902,
#                         'name': 'Shedd Aquarium',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'LF-001',
#                         'station_id': '3'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a378ca-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.856268,
#                         'lon': -87.613348,
#                         'name': 'Burnham Harbor',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1504000163',
#                         'station_id': '4'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.874053,
#                         'lon': -87.627716,
#                         'name': 'State St & Harrison St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000036',
#                         'station_id': '5'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a38363-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886976,
#                         'lon': -87.612813,
#                         'name': 'Dusable Harbor',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000064',
#                         'station_id': '6'},
#                        {'capacity': 17,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3888b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88634906269,
#                         'lon': -87.6175165471,
#                         'name': 'Field Blvd & South Water St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000036',
#                         'station_id': '7'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39301-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.82879201994,
#                         'lon': -87.6806044594,
#                         'name': 'Leavitt St & Archer Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000068',
#                         'station_id': '9'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3983e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.76663823695,
#                         'lon': -87.5764501141,
#                         'name': 'Jeffery Blvd & 71st St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000018',
#                         'station_id': '11'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39d55-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.7664094567,
#                         'lon': -87.5656875719,
#                         'name': 'South Shore Dr & 71st St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000002',
#                         'station_id': '12'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.932418,
#                         'lon': -87.652705,
#                         'name': 'Wilton Ave & Diversey Pkwy',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000014',
#                         'station_id': '13'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a7b4-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858086,
#                         'lon': -87.651073,
#                         'name': 'Morgan St & 18th St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000018',
#                         'station_id': '14'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858166,
#                         'lon': -87.656495,
#                         'name': 'Racine Ave & 18th St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000019',
#                         'station_id': '15'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910337,
#                         'lon': -87.670072,
#                         'name': 'Paulina Ave & North Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000037',
#                         'station_id': '16'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b731-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.903119,
#                         'lon': -87.673935,
#                         'name': 'Honore St & Division St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000034',
#                         'station_id': '17'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3bc53-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.883132,
#                         'lon': -87.637321,
#                         'name': 'Wacker Dr & Washington St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000072',
#                         'station_id': '18'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c174-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868968,
#                         'lon': -87.659141,
#                         'name': 'Loomis St & Taylor St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000023',
#                         'station_id': '19'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c696-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910522,
#                         'lon': -87.653106,
#                         'name': 'Sheffield Ave & Kingsbury St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000021',
#                         'station_id': '20'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3cbac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87772613,
#                         'lon': -87.65478743,
#                         'name': 'Aberdeen St & Jackson Blvd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000027',
#                         'station_id': '21'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d1b8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8694821,
#                         'lon': -87.6554864,
#                         'name': 'May St & Taylor St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000043',
#                         'station_id': '22'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d6f0-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902924,
#                         'lon': -87.637715,
#                         'name': 'Orleans St & Elm St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000006',
#                         'station_id': '23'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3dc37-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8925,
#                         'lon': -87.6207,
#                         'name': 'Fairbanks Ct & Grand Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000003',
#                         'station_id': '24'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e158-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89766,
#                         'lon': -87.62351,
#                         'name': 'Michigan Ave & Pearson St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000024',
#                         'station_id': '25'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e67b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.890359,
#                         'lon': -87.617532,
#                         'name': 'McClurg Ct & Illinois St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000013',
#                         'station_id': '26'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3eb9a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91021,
#                         'lon': -87.6435,
#                         'name': 'Larrabee St & North Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000008',
#                         'station_id': '27'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91468,
#                         'lon': -87.64332,
#                         'name': 'Larrabee St & Menomonee St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000007',
#                         'station_id': '28'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f5e9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90068,
#                         'lon': -87.6626,
#                         'name': 'Noble St & Milwaukee Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000028',
#                         'station_id': '29'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3fb5d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899643,
#                         'lon': -87.6677,
#                         'name': 'Ashland Ave & Augusta Blvd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000018',
#                         'station_id': '30'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40088-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896776,
#                         'lon': -87.635633,
#                         'name': 'Franklin St & Chicago Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000020',
#                         'station_id': '31'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a405a1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87464,
#                         'lon': -87.65703,
#                         'name': 'Racine Ave & Congress Pkwy',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000025',
#                         'station_id': '32'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40ad8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877181,
#                         'lon': -87.627844,
#                         'name': 'State St & Van Buren St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000035',
#                         'station_id': '33'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9267559875,
#                         'lon': -87.6344287848,
#                         'name': 'Cannon Dr & Fullerton Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000015',
#                         'station_id': '34'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41526-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892278,
#                         'lon': -87.612043,
#                         'name': 'Streeter Dr & Grand Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'LF-003',
#                         'station_id': '35'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41af5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8777079559,
#                         'lon': -87.6353211408,
#                         'name': 'Franklin St & Jackson Blvd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000025',
#                         'station_id': '36'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4203a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8793563587,
#                         'lon': -87.6297910363,
#                         'name': 'Dearborn St & Adams St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000005',
#                         'station_id': '37'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42574-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88602082773,
#                         'lon': -87.6308760584,
#                         'name': 'Clark St & Lake St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000012',
#                         'station_id': '38'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42a93-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87947235235,
#                         'lon': -87.6256886059,
#                         'name': 'Wabash Ave & Adams St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000015',
#                         'station_id': '39'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42fa7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87934437346,
#                         'lon': -87.6319852213,
#                         'name': 'LaSalle St & Adams St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000034',
#                         'station_id': '40'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a434ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87207763285,
#                         'lon': -87.6295437729,
#                         'name': 'Federal St & Polk St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000035',
#                         'station_id': '41'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43a25-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.852619,
#                         'lon': -87.626488,
#                         'name': 'Wabash Ave & Cermak Rd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000001',
#                         'station_id': '42'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43f48-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88355,
#                         'lon': -87.62418,
#                         'name': 'Michigan Ave & Washington St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000031',
#                         'station_id': '43'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44476-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8847302006,
#                         'lon': -87.6277335692,
#                         'name': 'State St & Randolph St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000029',
#                         'station_id': '44'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4499f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.876243,
#                         'lon': -87.624426,
#                         'name': 'Michigan Ave & Ida B Wells Dr',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000010',
#                         'station_id': '45'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44ec7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89993001,
#                         'lon': -87.63443007,
#                         'name': 'Wells St & Walton St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000011',
#                         'station_id': '46'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a453fa-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.889187,
#                         'lon': -87.627754,
#                         'name': 'State St & Kinzie St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000040',
#                         'station_id': '47'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4591a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.897764,
#                         'lon': -87.642884,
#                         'name': 'Larrabee St & Kingsbury St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000009',
#                         'station_id': '48'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a45e3b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.881319815,
#                         'lon': -87.6295209193,
#                         'name': 'Dearborn St & Monroe St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000006',
#                         'station_id': '49'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46361-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8759326655,
#                         'lon': -87.6305845355,
#                         'name': 'Clark St & Ida B Wells Dr',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000009',
#                         'station_id': '50'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46896-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884576228,
#                         'lon': -87.63188991,
#                         'name': 'Clark St & Randolph St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000030',
#                         'station_id': '51'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46e71-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886024,
#                         'lon': -87.624117,
#                         'name': 'Michigan Ave & Lake St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000011',
#                         'station_id': '52'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4739d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894722,
#                         'lon': -87.634362,
#                         'name': 'Wells St & Huron St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000012',
#                         'station_id': '53'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a478c9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896362458,
#                         'lon': -87.6540612729,
#                         'name': 'Ogden Ave & Chicago Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000020',
#                         'station_id': '54'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a47dde-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.867324,
#                         'lon': -87.648625,
#                         'name': 'Halsted St & Roosevelt Rd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000017',
#                         'station_id': '55'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a482fb-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.888716036,
#                         'lon': -87.6444478533,
#                         'name': 'Desplaines St & Kinzie St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000003',
#                         'station_id': '56'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4881d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8671177825,
#                         'lon': -87.6410879593,
#                         'name': 'Clinton St & Roosevelt Rd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000038',
#                         'station_id': '57'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a48d5c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.916017,
#                         'lon': -87.668879,
#                         'name': 'Marshfield Ave & Cortland St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000039',
#                         'station_id': '58'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a49288-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.867227,
#                         'lon': -87.625961,
#                         'name': 'Wabash Ave & Roosevelt Rd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000002',
#                         'station_id': '59'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a497b6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9105780349,
#                         'lon': -87.6494219288,
#                         'name': 'Dayton St & North Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000042',
#                         'station_id': '60'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a49cd7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.907655,
#                         'lon': -87.672552,
#                         'name': 'Wood St & Milwaukee Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000033',
#                         'station_id': '61'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4a202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8513751729,
#                         'lon': -87.6188346489,
#                         'name': 'McCormick Place',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000004',
#                         'station_id': '62'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4a71e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.885637,
#                         'lon': -87.641823,
#                         'name': 'Clinton St & Lake St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000001',
#                         'station_id': '66'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ac3f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9256018819,
#                         'lon': -87.6537080423,
#                         'name': 'Sheffield Ave & Fullerton Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000016',
#                         'station_id': '67'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4b164-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.875885,
#                         'lon': -87.640795,
#                         'name': 'Clinton St & Tilden St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000013',
#                         'station_id': '68'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4b693-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9093960065,
#                         'lon': -87.6776919292,
#                         'name': 'Damen Ave & Pierce Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000041',
#                         'station_id': '69'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4bbba-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8854833079,
#                         'lon': -87.6523048564,
#                         'name': 'Morgan St & Lake St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000015',
#                         'station_id': '71'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4c0df-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.860384,
#                         'lon': -87.625813,
#                         'name': 'Wabash Ave & 16th St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000044',
#                         'station_id': '72'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4c618-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880422,
#                         'lon': -87.642746,
#                         'name': 'Jefferson St & Monroe St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000007',
#                         'station_id': '73'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4cb42-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.893626,
#                         'lon': -87.641527,
#                         'name': 'Kingsbury St & Erie St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000028',
#                         'station_id': '74'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4d069-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877245,
#                         'lon': -87.639366,
#                         'name': 'Canal St & Jackson Blvd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000008',
#                         'station_id': '75'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4d588-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880958,
#                         'lon': -87.616743,
#                         'name': 'Lake Shore Dr & Monroe St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000022',
#                         'station_id': '76'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4daa1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.882242,
#                         'lon': -87.641066,
#                         'name': 'Clinton St & Madison St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1305000032',
#                         'station_id': '77'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4e4e3-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880419,
#                         'lon': -87.655519,
#                         'name': 'Aberdeen St & Monroe St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000023',
#                         'station_id': '80'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ea00-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884241,
#                         'lon': -87.629634,
#                         'name': 'Daley Center Plaza',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000010',
#                         'station_id': '81'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ef26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.891578,
#                         'lon': -87.648384,
#                         'name': 'Milwaukee Ave & Grand Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000004',
#                         'station_id': '84'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4f46b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90096039,
#                         'lon': -87.62377664,
#                         'name': 'Michigan Ave & Oak St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000019',
#                         'station_id': '85'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4f993-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89637337,
#                         'lon': -87.66098386,
#                         'name': 'Eckhart Park',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000017',
#                         'station_id': '86'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4fec3-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.92556258,
#                         'lon': -87.65840426,
#                         'name': 'Racine Ave & Fullerton Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000026',
#                         'station_id': '87'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a503e5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884069,
#                         'lon': -87.656853,
#                         'name': 'Racine Ave & Randolph St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'TA1306000024',
#                         'station_id': '88'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a50991-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.874618,
#                         'lon': -87.632882,
#                         'name': 'Financial Pl & Ida B Wells Dr (Temp)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA1503000026',
#                         'station_id': '89'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a50ec8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8810317,
# ...
#                         'name': 'Lakefront Trail & Wilson Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '639',
#                         'station_id': '639'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b42a3e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.949923,
#                         'lon': -87.713949,
#                         'name': 'Bernard St & Elston Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '640',
#                         'station_id': '640'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b42f5f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.914166,
#                         'lon': -87.716755,
#                         'name': 'Central Park Ave & Bloomingdale Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '641',
#                         'station_id': '641'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b43478-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894745,
#                         'lon': -87.756895,
#                         'name': 'Latrobe Ave & Chicago Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '642',
#                         'station_id': '642'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892048,
#                         'lon': -87.689397,
#                         'name': 'Smith Park (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '643',
#                         'station_id': '643'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b43eb7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868563,
#                         'lon': -87.686234,
#                         'name': 'Western Ave & Fillmore St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '644',
#                         'station_id': '644'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b443ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.826712,
#                         'lon': -87.683144,
#                         'name': 'Archer (Damen) Ave & 37th St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '645',
#                         'station_id': '645'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4497a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.796642,
#                         'lon': -87.625923,
#                         'name': 'State St & 54th St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '646',
#                         'station_id': '646'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b44eba-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.786691,
#                         'lon': -87.655859,
#                         'name': 'Elizabeth St & 59th St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '647',
#                         'station_id': '647'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b453f2-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.77987,
#                         'lon': -87.650919,
#                         'name': 'Carpenter St & 63rd St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '648',
#                         'station_id': '648'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4590f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.779835,
#                         'lon': -87.634774,
#                         'name': 'Stewart Ave & 63rd St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '649',
#                         'station_id': '649'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b45e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.768898,
#                         'lon': -87.635876,
#                         'name': 'Eggleston Ave & 69th St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '650',
#                         'station_id': '650'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4633a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.765286,
#                         'lon': -87.621748,
#                         'name': 'Michigan Ave & 71st St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '651',
#                         'station_id': '651'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46866-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.766,
#                         'lon': -87.611726,
#                         'name': 'Rhodes Ave & 71st St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '652',
#                         'station_id': '652'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46d7b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.780595,
#                         'lon': -87.584846,
#                         'name': 'Cornell Dr & Hayes Dr',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '653',
#                         'station_id': '653'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4728f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.883073,
#                         'lon': -87.656952,
#                         'name': 'Racine Ave & Washington Blvd (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '654',
#                         'station_id': '654'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b477ac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.979851,
#                         'lon': -87.681932,
#                         'name': 'Hoyne Ave & Balmoral Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '655',
#                         'station_id': '655'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b47cbc-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.885951,
#                         'lon': -87.677009,
#                         'name': 'Damen Ave & Walnut (Lake) St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA17018054',
#                         'station_id': '656'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899181,
#                         'lon': -87.6722,
#                         'name': 'Wood St & Augusta Blvd',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '657',
#                         'station_id': '657'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b486f2-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902997,
#                         'lon': -87.683825,
#                         'name': 'Leavitt St & Division St (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '658',
#                         'station_id': '658'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b48c07-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.895501,
#                         'lon': -87.682017,
#                         'name': 'Leavitt St & Chicago Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '659',
#                         'station_id': '659'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49122-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.004583,
#                         'lon': -87.661406,
#                         'name': 'Sheridan Rd & Columbia Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '660',
#                         'station_id': '660'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4963f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.057044,
#                         'lon': -87.686554,
#                         'name': 'Evanston Civic Center',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '661',
#                         'station_id': '661'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49b4c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.023463,
#                         'lon': -87.699595,
#                         'name': 'Dodge Ave & Mulford St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '662',
#                         'station_id': '662'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4a05c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.064854,
#                         'lon': -87.715297,
#                         'name': 'Lincolnwood Dr & Central St',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '663',
#                         'station_id': '663'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4a579-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.939354,
#                         'lon': -87.683282,
#                         'name': 'Leavitt St & Belmont Ave (*)',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': 'KA17018068',
#                         'station_id': '664'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4aa91-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.747363,
#                         'lon': -87.580046,
#                         'name': 'South Chicago Ave & Elliot Ave',
#                         'rental_methods': ['KEY', 'TRANSITCARD', 'CREDITCARD'],
#                         'short_name': '665',
#                         'station_id': '665'}]},
#  'last_updated': 1563066929,
#  'ttl': 2}

# %%
db_connection = psycopg2.connect(host='129.105.208.229',dbname="postgres", user="login" , password="pass")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# %%
db_connection = psycopg2.connect(host='129.105.208.229',dbname="chicago_divvy_stations_status", user="login" , password="pass")


cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension

# cursor.execute("CREATE EXTENSION postgis;")

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id INTEGER,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            int(df__stations['station_id'].iloc[x]),
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype(int)
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    now = datetime.now()
    timedate = ( (str(now.now())).split('.')[0]).split(' ')[0] + ' ' + ((str(now.now())).split('.')[0]).split(' ')[1]
 
    print(timedate, ' : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...')
    time.sleep(120)    
    continue
# Out:
# 2019-07-13 20:15:56  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:18:16  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:20:36  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:22:56  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:25:19  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:27:38  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:29:58  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:32:18  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:34:37  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:36:57  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:39:18  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:41:39  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:43:58  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:46:19  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:48:38  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:50:58  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:53:18  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:55:37  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 20:57:57  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:00:19  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:02:38  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:04:59  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:07:19  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:09:40  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:12:00  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:14:19  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:16:40  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:19:01  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:21:22  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:23:43  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:26:05  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:28:26  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:30:46  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:33:08  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:35:30  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:37:49  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:40:10  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:42:30  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:44:51  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:47:12  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:49:34  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:51:55  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:54:17  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:56:38  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 21:58:59  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:01:20  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:03:43  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:06:04  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:08:24  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:10:44  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:13:04  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:15:24  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:17:44  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:20:03  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:22:23  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:24:43  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:27:04  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:29:25  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:31:44  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:34:04  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:36:25  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:38:45  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:41:05  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:43:26  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2019-07-13 22:45:46  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...

# %%
# close connection at the end of the script

db_connection.close()
